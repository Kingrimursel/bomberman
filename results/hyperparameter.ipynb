# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
import matplotlib.cbook

# %%
plt.rc('lines', linewidth=0.1)
file = '/Users/etiennestock/Documents/bomberman/workspace/bomberman/agent_code/own_coin/logs/analysis/kgb_first_opt/optimization_landscape_new.fig.pickle'
a = pickle.load(open(file, 'rb'))

plt.xlabel(r'$\gamma$')
plt.ylabel(r'$\alpha$')

plt.plot(1, 0.4, 3, color="red")

plt.xticks([0.0, 0.2, 0.4, 0.6, 0.8, 1])
plt.yticks([0.0, 0.2, 0.4, 0.6, 0.8, 1])

plt.xlim((0, 1))
plt.ylim((0, 1))
# Out:
# Axes3DSubplot(0.22375,0.11;0.5775x0.77)
