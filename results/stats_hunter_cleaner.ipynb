# %%
import pickle

import numpy as np
from matplotlib import pyplot as plt
from collections import namedtuple, deque
import random

# %%
bombs = np.array([22388,22517,17950,18517])
coins = np.array([2269,2802,1856,1998])
kills = np.array([400,219,222,201])
score = np.array([4269,3897,2966,3003])
suicides = np.array([319,415,568,533])
time = np.array([2002,1660,259,270])

agents = np.array(['Hunter Agent', 'Cleaner Agent', 'Rule based', 'Rule based'])

# %%
# plotting
plt.rc('font', size=20) #controls default text size
x = np.linspace(0, 13)
plt.figure(figsize=(15, 9))


plt.plot([0,1,2,3], score, linewidth=3, color='navy', label='Score [Count]')
plt.plot([0,1,2,3], coins, linewidth=3, color='red', label='Coins [Count]')
plt.plot([0,1,2,3], kills*5, linewidth=3, color='grey', label=r'$5 \cdot$Kills [Count]')
plt.plot([0,1,2,3], suicides*5, linewidth=3, color='orange', label=r'$5 \cdot$ Suicides [Count]')
plt.plot([0,1,2,3], time, linewidth=3, color='black', label='Time [a.u.]')

plt.xticks([0,1,2,3], agents)
plt.ylim(100,4700)
plt.title('Statistic for 1000 games')
plt.legend(loc='upper right')

plt.savefig('hunter_against_cleaner_score.png')
plt.show()
